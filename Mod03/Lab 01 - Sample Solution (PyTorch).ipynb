# %% [markdown]
# ### Install PyTorch
#
# > *Note: The following `pip install` commands install the CPU-based version of PyTorch on Linux, which is appropriate for the Azure Notebooks environment. For instructions on how to install the PyTorch and TorchVision packages on your own system, see https://pytorch.org/get-started/locally/*

# %%
# Install PyTorch
#!pip install https://download.pytorch.org/whl/cpu/torch-1.0.1.post2-cp36-cp36m-linux_x86_64.whl
#!pip install torchvision

# Import PyTorch libraries
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

print("Libraries imported - ready to use PyTorch", torch.__version__)
# Out:
# Libraries imported - ready to use PyTorch 1.3.1

# %% [markdown]
# ### Load Data

# %%
# Function to ingest data using training and test loaders
def load_dataset(data_path):
    # Load all of the images
    transformation = transforms.Compose([
        # Randomly augment the image data
        transforms.RandomHorizontalFlip(0.5),
        transforms.RandomRotation(180),
        # transform to tensors
        transforms.ToTensor(),
        # Normalize the pixel values (in R, G, and B channels)
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Load all of the images, transforming them
    full_dataset = torchvision.datasets.ImageFolder(
        root=data_path,
        transform=transformation
    )
    
    
    # Split into training (70% and testing (30%) datasets)
    train_size = int(0.7 * len(full_dataset))
    test_size = len(full_dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [train_size, test_size])
    
    # define a loader for the training data we can iterate through in 50-image batches
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=images_per_batch,
        num_workers=1,
        shuffle=False
    )
    
    # define a loader for the testing data we can iterate through in 50-image batches
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=images_per_batch,
        num_workers=1,
        shuffle=False
    )
        
    return train_loader, test_loader

import os

train_folder = "../data/classification/training"
img_size = (128,128)
images_per_batch = 18

# Get the class names
classes = os.listdir(train_folder)
classes.sort()
print(classes)

# Get the iterative dataloaders for test and training data
train_loader, test_loader = load_dataset(train_folder)
# Out:
# ['automobile', 'plane', 'train']

# %% [markdown]
# ### Define a Neural Network Model

# %%
# Create a neural net class
class Net(nn.Module):
    # Constructor
    def __init__(self, num_classes=3):
        super(Net, self).__init__()
        
        # Our images are RGB, so input channels = 3. We'll apply 24 filters in the first convolutional layer
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 24 input channels, and generates 24 outputs
        self.conv2 = nn.Conv2d(in_channels=24, out_channels=24, kernel_size=3, stride=1, padding=1)
        
        # A second convolutional layer takes 24 input channels, and generates 48 outputs
        self.conv3 = nn.Conv2d(in_channels=24, out_channels=48, kernel_size=3, stride=1, padding=1)
        
        # We'll apply max pooling with a kernel size of 2
        self.pool = nn.MaxPool2d(kernel_size=2)
        
        # A drop layer deletes 50% of the features to help prevent overfitting
        self.drop = nn.Dropout2d(p=0.5)
        
        # Our 128x128 image tensors will be pooled three times with a kernel size of 2. 128/2/2/2 is 16.
        # So our feature tensors are now 32 x 32, and we've generated 48 of them so our array is 16x16x48
        # We need to flatten these and feed them to a fully-connected layer
        # to map them to  the probability for each class
        self.fc = nn.Linear(in_features=16 * 16 * 48, out_features=num_classes)

    def forward(self, x):
        # Use a relu activation function after convolution 1 and pool
        x = F.relu(self.pool(self.conv1(x)))
      
        # Use a relu activation function after convolution 2 and pool
        x = F.relu(self.pool(self.conv2(x)))
        
        # Use a relu activation function after convolution 2)
        x = F.relu(self.conv2(x))
        
        # Use a relu activation function after convolution 2
        x = F.relu(self.conv2(x))
        
         # Use a relu activation function after convolution 3 and pool
        x = F.relu(self.pool(self.conv3(x)))
        
        # Select some features to drop to prevent overfitting (only drop during training)
        x = F.dropout(self.drop(x), training=self.training)
        
        # Flatten
        x = x.view(-1, 16 * 16 * 48)
        # Feed to fully-connected layer to predict class
        x = self.fc(x)
        # Return class probabilities via a log_softmax function 
        return F.log_softmax(x, dim=1)
    
device = "cpu"
if (torch.cuda.is_available()):
    # if GPU available, use cuda (on a cpu, training will take a considerable length of time!)
    device = "cuda"

# Create an instance of the model class and allocate it to the device
model = Net(num_classes=len(classes)).to(device)

print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(24, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (drop): Dropout2d(p=0.5, inplace=False)
#   (fc): Linear(in_features=12288, out_features=3, bias=True)
# )

# %% [markdown]
# ### Train the Model

# %%
def train(model, device, train_loader, optimizer, epoch):
    # Set the model to training mode
    model.train()
    train_loss = 0
    print("Epoch:", epoch)
    # Process the images in batches
    for batch_idx, (data, target) in enumerate(train_loader):
        # Use the CPU or GPU as appropriate
        data, target = data.to(device), target.to(device)
        
        # Reset the optimizer
        optimizer.zero_grad()
        
        # Push the data forward through the model layers
        output = model(data)
        
        # Get the loss
        loss = loss_criteria(output, target)

        # Keep a running total
        train_loss += loss.item()
        
        # Backpropagate
        loss.backward()
        optimizer.step()
        
        # Print metrics so we see some progress
        print('\tTraining batch {} Loss: {:.6f}'.format(batch_idx + 1, loss.item()))
            
    # return average loss for the epoch
    avg_loss = train_loss / (batch_idx+1)
    print('Training set: Average loss: {:.6f}'.format(avg_loss))
    return avg_loss
            
            
def test(model, device, test_loader):
    # Switch the model to evaluation mode (so we don't backpropagate or drop)
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        batch_count = 0
        for data, target in test_loader:
            batch_count += 1
            data, target = data.to(device), target.to(device)
            
            # Get the predicted classes for this batch
            output = model(data)
            
            # Calculate the loss for this batch
            test_loss += loss_criteria(output, target).item()
            
            # Calculate the accuracy for this batch
            _, predicted = torch.max(output.data, 1)
            correct += torch.sum(target==predicted).item()

    # Calculate the average loss and total accuracy for this epoch
    avg_loss = test_loss/batch_count
    print('Validation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        avg_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    
    # return average loss for the epoch
    return avg_loss
    
    
# Use an "Adam" optimizer to adjust weights
# (see https://pytorch.org/docs/stable/optim.html#algorithms for details of supported algorithms)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Specify the loss criteria
loss_criteria = nn.CrossEntropyLoss()

# Track metrics in these arrays
epoch_nums = []
training_loss = []
validation_loss = []

# Train over 30 epochs
epochs = 30
print('Training on', device)
for epoch in range(1, epochs + 1):
        train_loss = train(model, device, train_loader, optimizer, epoch)
        test_loss = test(model, device, test_loader)
        epoch_nums.append(epoch)
        training_loss.append(train_loss)
        validation_loss.append(test_loss)
# Out:
# Training on cpu
# Epoch: 1
# 	Training batch 1 Loss: 1.095512
# 	Training batch 2 Loss: 1.084272
# 	Training batch 3 Loss: 1.127370
# 	Training batch 4 Loss: 1.191540
# 	Training batch 5 Loss: 1.089558
# 	Training batch 6 Loss: 1.154320
# 	Training batch 7 Loss: 1.113004
# 	Training batch 8 Loss: 1.172266
# 	Training batch 9 Loss: 1.095750
# 	Training batch 10 Loss: 1.051697
# Training set: Average loss: 1.117529
# Validation set: Average loss: 1.1011, Accuracy: 25/72 (35%)
#
# Epoch: 2
# 	Training batch 1 Loss: 1.114679
# 	Training batch 2 Loss: 1.100421
# 	Training batch 3 Loss: 1.113944
# 	Training batch 4 Loss: 1.106238
# 	Training batch 5 Loss: 1.086355
# 	Training batch 6 Loss: 1.114346
# 	Training batch 7 Loss: 1.114092
# 	Training batch 8 Loss: 1.099268
# 	Training batch 9 Loss: 1.109017
# 	Training batch 10 Loss: 1.031473
# Training set: Average loss: 1.098983
# Validation set: Average loss: 1.0793, Accuracy: 25/72 (35%)
#
# Epoch: 3
# 	Training batch 1 Loss: 1.122522
# 	Training batch 2 Loss: 1.106036
# 	Training batch 3 Loss: 1.109853
# 	Training batch 4 Loss: 1.082671
# 	Training batch 5 Loss: 1.077465
# 	Training batch 6 Loss: 1.085653
# 	Training batch 7 Loss: 1.108377
# 	Training batch 8 Loss: 1.080351
# 	Training batch 9 Loss: 1.049023
# 	Training batch 10 Loss: 1.130199
# Training set: Average loss: 1.095215
# Validation set: Average loss: 1.0531, Accuracy: 32/72 (44%)
#
# Epoch: 4
# 	Training batch 1 Loss: 1.033048
# 	Training batch 2 Loss: 1.021682
# 	Training batch 3 Loss: 1.066907
# 	Training batch 4 Loss: 1.014082
# 	Training batch 5 Loss: 1.035042
# 	Training batch 6 Loss: 1.071232
# 	Training batch 7 Loss: 1.030001
# 	Training batch 8 Loss: 0.923168
# 	Training batch 9 Loss: 0.987921
# 	Training batch 10 Loss: 0.889710
# Training set: Average loss: 1.007279
# Validation set: Average loss: 0.9861, Accuracy: 37/72 (51%)
#
# Epoch: 5
# 	Training batch 1 Loss: 0.980144
# 	Training batch 2 Loss: 0.884591
# 	Training batch 3 Loss: 1.013436
# 	Training batch 4 Loss: 1.076183
# 	Training batch 5 Loss: 0.944996
# 	Training batch 6 Loss: 1.004117
# 	Training batch 7 Loss: 0.860749
# 	Training batch 8 Loss: 0.792292
# 	Training batch 9 Loss: 0.904670
# 	Training batch 10 Loss: 0.673389
# Training set: Average loss: 0.913457
# Validation set: Average loss: 0.9378, Accuracy: 41/72 (57%)
#
# Epoch: 6
# 	Training batch 1 Loss: 0.808362
# 	Training batch 2 Loss: 0.881674
# 	Training batch 3 Loss: 1.077484
# 	Training batch 4 Loss: 0.847236
# 	Training batch 5 Loss: 0.917313
# 	Training batch 6 Loss: 0.972444
# 	Training batch 7 Loss: 1.051021
# 	Training batch 8 Loss: 0.683941
# 	Training batch 9 Loss: 1.022646
# 	Training batch 10 Loss: 0.786952
# Training set: Average loss: 0.904907
# Validation set: Average loss: 0.9574, Accuracy: 32/72 (44%)
#
# Epoch: 7
# 	Training batch 1 Loss: 0.881563
# 	Training batch 2 Loss: 0.824033
# 	Training batch 3 Loss: 0.751941
# 	Training batch 4 Loss: 0.812096
# 	Training batch 5 Loss: 0.815189
# 	Training batch 6 Loss: 0.889862
# 	Training batch 7 Loss: 1.047686
# 	Training batch 8 Loss: 0.722013
# 	Training batch 9 Loss: 0.874063
# 	Training batch 10 Loss: 0.514037
# Training set: Average loss: 0.813248
# Validation set: Average loss: 0.9732, Accuracy: 37/72 (51%)
#
# Epoch: 8
# 	Training batch 1 Loss: 0.866401
# 	Training batch 2 Loss: 0.728083
# 	Training batch 3 Loss: 0.947464
# 	Training batch 4 Loss: 0.926848
# 	Training batch 5 Loss: 0.902201
# 	Training batch 6 Loss: 0.746710
# 	Training batch 7 Loss: 1.163166
# 	Training batch 8 Loss: 0.752342
# 	Training batch 9 Loss: 0.848068
# 	Training batch 10 Loss: 0.426987
# Training set: Average loss: 0.830827
# Validation set: Average loss: 0.9076, Accuracy: 40/72 (56%)
#
# Epoch: 9
# 	Training batch 1 Loss: 0.882202
# 	Training batch 2 Loss: 0.738278
# 	Training batch 3 Loss: 0.738146
# 	Training batch 4 Loss: 0.741283
# 	Training batch 5 Loss: 0.703355
# 	Training batch 6 Loss: 0.880288
# 	Training batch 7 Loss: 0.967407
# 	Training batch 8 Loss: 0.711887
# 	Training batch 9 Loss: 0.935167
# 	Training batch 10 Loss: 0.257653
# Training set: Average loss: 0.755567
# Validation set: Average loss: 0.8983, Accuracy: 40/72 (56%)
#
# Epoch: 10
# 	Training batch 1 Loss: 0.763596
# 	Training batch 2 Loss: 0.650650
# 	Training batch 3 Loss: 0.788092
# 	Training batch 4 Loss: 0.855675
# 	Training batch 5 Loss: 0.851231
# 	Training batch 6 Loss: 0.845427
# 	Training batch 7 Loss: 0.954930
# 	Training batch 8 Loss: 0.623329
# 	Training batch 9 Loss: 1.002887
# 	Training batch 10 Loss: 0.351638
# Training set: Average loss: 0.768746
# Validation set: Average loss: 0.9426, Accuracy: 39/72 (54%)
#
# Epoch: 11
# 	Training batch 1 Loss: 0.911716
# 	Training batch 2 Loss: 0.661722
# 	Training batch 3 Loss: 0.854585
# 	Training batch 4 Loss: 0.687823
# 	Training batch 5 Loss: 0.801367
# 	Training batch 6 Loss: 0.832194
# 	Training batch 7 Loss: 0.977217
# 	Training batch 8 Loss: 0.749078
# 	Training batch 9 Loss: 1.049777
# 	Training batch 10 Loss: 0.393179
# Training set: Average loss: 0.791866
# Validation set: Average loss: 0.8935, Accuracy: 33/72 (46%)
#
# Epoch: 12
# 	Training batch 1 Loss: 0.713755
# 	Training batch 2 Loss: 0.625062
# 	Training batch 3 Loss: 0.840957
# 	Training batch 4 Loss: 0.827599
# 	Training batch 5 Loss: 0.627362
# 	Training batch 6 Loss: 0.794402
# 	Training batch 7 Loss: 0.991127
# 	Training batch 8 Loss: 0.810052
# 	Training batch 9 Loss: 0.886231
# 	Training batch 10 Loss: 0.219358
# Training set: Average loss: 0.733591
# Validation set: Average loss: 0.9064, Accuracy: 40/72 (56%)
#
# Epoch: 13
# 	Training batch 1 Loss: 0.709674
# 	Training batch 2 Loss: 0.807105
# 	Training batch 3 Loss: 0.930793
# 	Training batch 4 Loss: 0.795423
# 	Training batch 5 Loss: 0.600067
# 	Training batch 6 Loss: 0.872071
# 	Training batch 7 Loss: 1.055742
# 	Training batch 8 Loss: 0.663205
# 	Training batch 9 Loss: 0.928093
# 	Training batch 10 Loss: 0.278443
# Training set: Average loss: 0.764062
# Validation set: Average loss: 0.8438, Accuracy: 47/72 (65%)
#
# Epoch: 14
# 	Training batch 1 Loss: 0.809760
# 	Training batch 2 Loss: 0.680564
# 	Training batch 3 Loss: 0.726909
# 	Training batch 4 Loss: 0.848567
# 	Training batch 5 Loss: 0.557457
# 	Training batch 6 Loss: 0.918414
# 	Training batch 7 Loss: 0.879030
# 	Training batch 8 Loss: 0.654462
# 	Training batch 9 Loss: 1.021256
# 	Training batch 10 Loss: 0.349102
# Training set: Average loss: 0.744552
# Validation set: Average loss: 0.9044, Accuracy: 39/72 (54%)
#
# Epoch: 15
# 	Training batch 1 Loss: 0.757222
# 	Training batch 2 Loss: 0.661863
# 	Training batch 3 Loss: 0.803391
# 	Training batch 4 Loss: 0.628127
# 	Training batch 5 Loss: 0.626250
# 	Training batch 6 Loss: 1.031255
# 	Training batch 7 Loss: 1.016098
# 	Training batch 8 Loss: 0.580456
# 	Training batch 9 Loss: 1.012240
# 	Training batch 10 Loss: 0.293068
# Training set: Average loss: 0.740997
# Validation set: Average loss: 0.9473, Accuracy: 37/72 (51%)
#
# Epoch: 16
# 	Training batch 1 Loss: 1.066983
# 	Training batch 2 Loss: 0.609536
# 	Training batch 3 Loss: 0.751262
# 	Training batch 4 Loss: 0.847200
# 	Training batch 5 Loss: 0.592705
# 	Training batch 6 Loss: 0.774950
# 	Training batch 7 Loss: 0.971937
# 	Training batch 8 Loss: 0.677731
# 	Training batch 9 Loss: 0.800901
# 	Training batch 10 Loss: 0.191232
# Training set: Average loss: 0.728444
# Validation set: Average loss: 0.8456, Accuracy: 44/72 (61%)
#
# Epoch: 17
# 	Training batch 1 Loss: 0.893119
# 	Training batch 2 Loss: 0.631172
# 	Training batch 3 Loss: 0.711357
# 	Training batch 4 Loss: 0.767421
# 	Training batch 5 Loss: 0.599748
# 	Training batch 6 Loss: 0.764387
# 	Training batch 7 Loss: 0.991849
# 	Training batch 8 Loss: 0.643295
# 	Training batch 9 Loss: 0.901502
# 	Training batch 10 Loss: 0.202626
# Training set: Average loss: 0.710648
# Validation set: Average loss: 0.9377, Accuracy: 39/72 (54%)
#
# Epoch: 18
# 	Training batch 1 Loss: 0.776167
# 	Training batch 2 Loss: 0.762259
# 	Training batch 3 Loss: 0.723628
# 	Training batch 4 Loss: 0.706723
# 	Training batch 5 Loss: 0.617702
# 	Training batch 6 Loss: 0.750667
# 	Training batch 7 Loss: 0.942179
# 	Training batch 8 Loss: 0.554515
# 	Training batch 9 Loss: 0.804502
# 	Training batch 10 Loss: 0.124884
# Training set: Average loss: 0.676322
# Validation set: Average loss: 0.8941, Accuracy: 43/72 (60%)
#
# Epoch: 19
# 	Training batch 1 Loss: 0.770567
# 	Training batch 2 Loss: 0.577774
# 	Training batch 3 Loss: 0.776409
# 	Training batch 4 Loss: 0.797689
# 	Training batch 5 Loss: 0.414428
# 	Training batch 6 Loss: 0.845408
# 	Training batch 7 Loss: 0.770627
# 	Training batch 8 Loss: 0.568111
# 	Training batch 9 Loss: 0.915947
# 	Training batch 10 Loss: 0.220305
# Training set: Average loss: 0.665726
# Validation set: Average loss: 0.9472, Accuracy: 40/72 (56%)
#
# Epoch: 20
# 	Training batch 1 Loss: 0.726626
# 	Training batch 2 Loss: 0.476647
# 	Training batch 3 Loss: 0.802895
# 	Training batch 4 Loss: 0.835234
# 	Training batch 5 Loss: 0.521249
# 	Training batch 6 Loss: 0.812090
# 	Training batch 7 Loss: 0.767356
# 	Training batch 8 Loss: 0.597642
# 	Training batch 9 Loss: 0.851869
# 	Training batch 10 Loss: 0.172851
# Training set: Average loss: 0.656446
# Validation set: Average loss: 0.9743, Accuracy: 44/72 (61%)
#
# Epoch: 21
# 	Training batch 1 Loss: 0.878077
# 	Training batch 2 Loss: 0.812339
# 	Training batch 3 Loss: 0.790150
# 	Training batch 4 Loss: 0.798676
# 	Training batch 5 Loss: 0.580096
# 	Training batch 6 Loss: 0.896900
# 	Training batch 7 Loss: 1.076041
# 	Training batch 8 Loss: 0.611874
# 	Training batch 9 Loss: 0.810787
# 	Training batch 10 Loss: 0.311108
# Training set: Average loss: 0.756605
# Validation set: Average loss: 0.8657, Accuracy: 40/72 (56%)
#
# Epoch: 22
# 	Training batch 1 Loss: 0.705748
# 	Training batch 2 Loss: 0.614134
# 	Training batch 3 Loss: 0.820659
# 	Training batch 4 Loss: 0.755567
# 	Training batch 5 Loss: 0.556965
# 	Training batch 6 Loss: 0.916354
# 	Training batch 7 Loss: 0.841194
# 	Training batch 8 Loss: 0.629062
# 	Training batch 9 Loss: 0.873915
# 	Training batch 10 Loss: 0.145524
# Training set: Average loss: 0.685912
# Validation set: Average loss: 0.9034, Accuracy: 38/72 (53%)
#
# Epoch: 23
# 	Training batch 1 Loss: 0.875804
# 	Training batch 2 Loss: 0.547845
# 	Training batch 3 Loss: 0.790324
# 	Training batch 4 Loss: 0.790235
# 	Training batch 5 Loss: 0.533359
# 	Training batch 6 Loss: 0.819681
# 	Training batch 7 Loss: 0.859619
# 	Training batch 8 Loss: 0.615491
# 	Training batch 9 Loss: 0.766056
# 	Training batch 10 Loss: 0.161442
# Training set: Average loss: 0.675986
# Validation set: Average loss: 0.8574, Accuracy: 44/72 (61%)
#
# Epoch: 24
# 	Training batch 1 Loss: 0.781490
# 	Training batch 2 Loss: 0.703094
# 	Training batch 3 Loss: 0.671446
# 	Training batch 4 Loss: 0.673614
# 	Training batch 5 Loss: 0.541836
# 	Training batch 6 Loss: 0.725973
# 	Training batch 7 Loss: 1.164793
# 	Training batch 8 Loss: 0.628594
# 	Training batch 9 Loss: 0.792894
# 	Training batch 10 Loss: 0.154075
# Training set: Average loss: 0.683781
# Validation set: Average loss: 0.8907, Accuracy: 40/72 (56%)
#
# Epoch: 25
# 	Training batch 1 Loss: 0.787393
# 	Training batch 2 Loss: 0.556584
# 	Training batch 3 Loss: 0.801324
# 	Training batch 4 Loss: 0.832726
# 	Training batch 5 Loss: 0.527034
# 	Training batch 6 Loss: 0.652973
# 	Training batch 7 Loss: 0.747544
# 	Training batch 8 Loss: 0.598735
# 	Training batch 9 Loss: 0.736409
# 	Training batch 10 Loss: 0.289754
# Training set: Average loss: 0.653048
# Validation set: Average loss: 0.8250, Accuracy: 42/72 (58%)
#
# Epoch: 26
# 	Training batch 1 Loss: 0.670021
# 	Training batch 2 Loss: 0.589064
# 	Training batch 3 Loss: 0.745878
# 	Training batch 4 Loss: 0.704510
# 	Training batch 5 Loss: 0.591741
# 	Training batch 6 Loss: 0.902852
# 	Training batch 7 Loss: 0.725860
# 	Training batch 8 Loss: 0.631891
# 	Training batch 9 Loss: 0.980992
# 	Training batch 10 Loss: 0.368127
# Training set: Average loss: 0.691094
# Validation set: Average loss: 0.8527, Accuracy: 42/72 (58%)
#
# Epoch: 27
# 	Training batch 1 Loss: 0.802729
# 	Training batch 2 Loss: 0.640004
# 	Training batch 3 Loss: 0.737202
# 	Training batch 4 Loss: 0.734703
# 	Training batch 5 Loss: 0.458157
# 	Training batch 6 Loss: 0.770528
# 	Training batch 7 Loss: 0.846098
# 	Training batch 8 Loss: 0.548178
# 	Training batch 9 Loss: 0.763649
# 	Training batch 10 Loss: 0.167430
# Training set: Average loss: 0.646868
# Validation set: Average loss: 0.9363, Accuracy: 38/72 (53%)
#
# Epoch: 28
# 	Training batch 1 Loss: 0.776498
# 	Training batch 2 Loss: 0.680560
# 	Training batch 3 Loss: 0.849782
# 	Training batch 4 Loss: 0.736757
# 	Training batch 5 Loss: 0.659225
# 	Training batch 6 Loss: 0.712825
# 	Training batch 7 Loss: 0.775473
# 	Training batch 8 Loss: 0.664746
# 	Training batch 9 Loss: 0.859267
# 	Training batch 10 Loss: 0.260212
# Training set: Average loss: 0.697534
# Validation set: Average loss: 0.8528, Accuracy: 45/72 (62%)
#
# Epoch: 29
# 	Training batch 1 Loss: 0.753168
# 	Training batch 2 Loss: 0.601125
# 	Training batch 3 Loss: 0.772769
# 	Training batch 4 Loss: 0.692273
# 	Training batch 5 Loss: 0.555308
# 	Training batch 6 Loss: 0.580717
# 	Training batch 7 Loss: 0.597025
# 	Training batch 8 Loss: 0.609117
# 	Training batch 9 Loss: 0.662293
# 	Training batch 10 Loss: 0.242184
# Training set: Average loss: 0.606598
# Validation set: Average loss: 0.9024, Accuracy: 42/72 (58%)
#
# Epoch: 30
# 	Training batch 1 Loss: 0.663413
# 	Training batch 2 Loss: 0.523679
# 	Training batch 3 Loss: 0.779550
# 	Training batch 4 Loss: 0.803641
# 	Training batch 5 Loss: 0.425266
# 	Training batch 6 Loss: 0.642061
# 	Training batch 7 Loss: 0.773782
# 	Training batch 8 Loss: 0.734662
# 	Training batch 9 Loss: 0.882230
# 	Training batch 10 Loss: 0.127333
# Training set: Average loss: 0.635562
# Validation set: Average loss: 0.9323, Accuracy: 42/72 (58%)

# %% [markdown]
# ### View the Loss History

# %%
from matplotlib import pyplot as plt
# %matplotlib inline


plt.plot(epoch_nums, training_loss)
plt.plot(epoch_nums, validation_loss)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
#Pytorch doesn't have a built-in confusion matrix metric, so we'll use SciKit-Learn
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import numpy as np

truelabels = []
predictions = []
model.eval()
print("Getting predictions from test set...")
for data, target in test_loader:
    for label in target.data.numpy():
        truelabels.append(label)
    for prediction in model(data).data.numpy().argmax(1):
        predictions.append(prediction) 

# Plot the confusion matrix
cm = confusion_matrix(truelabels, predictions)
plt.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=85)
plt.yticks(tick_marks, classes)
plt.xlabel("Predicted Shape")
plt.ylabel("True Shape")
plt.show()
# Out:
# Getting predictions from test set...

# %% [markdown]
# ### Save the Model

# %%
# Save the model weights
model_file = 'vehicle-classifier.pt'
torch.save(model.state_dict(), model_file)
print("Model saved.")

# Delete the existing model variable
del model
# Out:
# Model saved.

# %% [markdown]
# ### Use the Model with New Data

# %%
# Helper function to resize image
def resize_image(src_img, size=(128,128), bg_color="white"): 
    from PIL import Image

    # rescale the image so the longest edge is the right size
    src_img.thumbnail(size, Image.ANTIALIAS)
    
    # Create a new image of the right shape
    new_image = Image.new("RGB", size, bg_color)
    
    # Paste the rescaled image onto the new background
    new_image.paste(src_img, (int((size[0] - src_img.size[0]) / 2), int((size[1] - src_img.size[1]) / 2)))
  
    # return the resized image
    return new_image

# Function to predict the class of an image
def predict_image(classifier, image_array):
   
    # Set the classifer model to evaluation mode
    classifier.eval()
    
    # These are the classes our model can predict
    class_names = ['automobile', 'plane', 'train']
    
    # Apply the same transformations as we did for the training images
    transformation = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])

    # Preprocess the imagees
    image_tensor = torch.stack([transformation(image).float() for image in image_array])

    # Turn the input into a Variable
    input_features = image_tensor

    # Predict the class of each input image
    predictions = classifier(input_features)
    
    predicted_classes = []
    # Convert the predictions to a numpy array 
    for prediction in predictions.data.numpy():
        # The prediction for each image is the probability for each class, e.g. [0.8, 0.1, 0.2]
        # So get the index of the highest probability
        class_idx = np.argmax(prediction)
        # And append the corresponding class name to the results
        predicted_classes.append(class_names[class_idx])
    return np.array(predicted_classes)

print("Functions created - ready to use model for inference.")
# Out:
# Functions created - ready to use model for inference.

# %%
import os
from random import randint
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
# %matplotlib inline

# load the saved model weights
model = Net(num_classes=3)
model.load_state_dict(torch.load(model_file))


#get the list of test image files
test_folder = '../data/classification/test'
test_image_files = os.listdir(test_folder)

# Empty array on which to store the images
image_arrays = []

size = (128,128)
background_color = "white"

fig = plt.figure(figsize=(12, 8))

# Get the images and show the predicted classes
for file_idx in range(len(test_image_files)):
    img = Image.open(os.path.join(test_folder, test_image_files[file_idx]))
    
    # resize the image so it matches the training set - it  must be the same size as the images on which the model was trained
    resized_img = np.array(resize_image(img, size, background_color))
                      
    # Add the image to the array of images
    image_arrays.append(resized_img)

# Get predictions from the array of image arrays
# Note that the model expects an array of 1 or more images - just like the batches on which it was trained
predictions = predict_image(model, np.array(image_arrays))

# plot easch image with its corresponding prediction
for idx in range(len(predictions)):
    a=fig.add_subplot(1,len(predictions),idx+1)
    imgplot = plt.imshow(image_arrays[idx])
    a.set_title(predictions[idx])
